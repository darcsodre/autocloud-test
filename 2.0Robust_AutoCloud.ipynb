# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
#from scipy.spatial import cKDTree

# %%
class DataCloud:
    N = 0  # Contador global de nuvens de dados
    
    def __init__(self, x):
        #Inicializa uma nova nuvem de dados com o primeiro ponto x
        self.n = 1  # Número de pontos na nuvem
        self.mean = x  # Média (centroide)
        self.variance = 0  # Variância inicial (0 para um único ponto)
        self.pertinency = 1  # Grau de pertinência
        DataCloud.N += 1  # Incrementa contador global

    def updateDataCloud(self , x):
        """Atualiza a nuvem com um novo ponto x usando as Eqs.recursivas 4 e 5 do artigo"""
        old_mean = self.mean
        old_variance = self.variance

        # Atualiza média (Eq. 4)
        self.mean = ((self.n - 1) * old_mean + x) / self.n

        # Atualiza variância (Eq. 5 corrigida, usando old_mean em vez da média já atualizada)
        self.variance = ((self.n - 1) / self.n) * old_variance + (1 / self.n) * np.linalg.norm(x - old_mean)**2

        self.n += 1  # Incrementa contador de pontos
        
        # Proteção contra variância zero após atualização
        self.variance = max(self.variance, 1e-6)

# %%
class AutoCloud():
    def __init__(self, m=2.5):  # Valor padrão (default) caso o usuário não especifique
        self.m = m  # Parâmetro de sensibilidade (Eq. 9)
        self.clouds = []  # Lista de DataClouds
        self.classIndex = []  # Histórico de classificações
        self.k = 0  # Contador de amostras processadas

        # Dicionário para rastrear amostras processadas
        self.sample_registry = {}


    def calculate_eccentricity(self, x, cloud):
        """Calcula a excentricidade normalizada (Eqs. 3 e 12)"""
        if cloud.n == 0 or cloud.variance == 0:
            return 1.0  # Máxima excentricidade se não houver dados
    
        term1 = 1 / cloud.n
        diff = cloud.mean - x
        term2 = (diff.T @ diff) / (cloud.n * cloud.variance)
        
        return term1 + term2  # Sem divisão por 2!


    def merge_clouds(self):
        """Fusão de clouds baseada na sobreposição das amostras (Eqs. 16-20)"""
        
        epsilon = 1e-6  # 🔹 Evita threshold = 0 se variância for zero
        
        i = 0
        while i < len(self.clouds):
            j = i + 1
            while j < len(self.clouds):
                #Calcula distância euclidiana entre as médias
                mean_diff = np.linalg.norm(self.clouds[i].mean - self.clouds[j].mean)
                
                # Proteção contra variância zero só na fusão
                var_i = self.clouds[i].variance + epsilon
                var_j = self.clouds[j].variance + epsilon
                threshold = self.m * (np.sqrt(var_i) + np.sqrt(var_j))

                if mean_diff < threshold:  # Usa Eq. 16 como critério de fusão
                    # Atualiza parâmetros da nova nuvem fundida (Eqs. 17-20)
                    ni, nj = self.clouds[i].n, self.clouds[j].n
                    mean_i, mean_j = self.clouds[i].mean, self.clouds[j].mean
                    var_i, var_j = self.clouds[i].variance, self.clouds[j].variance

                    # Atualiza número de pontos
                    self.clouds[i].n = ni + nj

                    # Atualiza média (Eq. 18)
                    self.clouds[i].mean = (ni * mean_i + nj * mean_j) / (ni + nj)

                    # Atualiza variância corretamente (Eq. 17)
                    self.clouds[i].variance = (ni * var_i + nj * var_j + 
                                            (ni * nj * np.linalg.norm(mean_i - mean_j) ** 2) / (ni + nj)) / (ni + nj)

                    # Atualiza classIndex com realocação de índices
                    for k, idx in enumerate(self.classIndex):
                        if idx == j:
                            self.classIndex[k] = i
                        elif idx > j:
                            self.classIndex[k] -= 1

                    # Remove `cloud j`
                    self.clouds.pop(j)
                    continue  # Mantém `i` fixo para reavaliar após fusão

                j += 1
            i += 1


    def calculate_quality(self):
        """Calcula a métrica de qualidade das fusões das clouds, baseada na Eq. 21 do artigo."""
        # Casos especiais
        if len(self.clouds) < 2:
            return 0.0

        total = 0.0
        min_distance = float('inf')
        eps = 1e-10  # Valor pequeno para evitar divisão por zero

        # Calcula a soma ponderada das variâncias
        for cloud in self.clouds:
            eccentricity = self.calculate_eccentricity(cloud.mean, cloud)
            typicality = max(0, 1 - (2 * eccentricity))  # Evita valores negativos
            total += (typicality**2) * (cloud.variance + eps)

        # Encontra a menor distância entre centróides de clusters distintos
        for i, c1 in enumerate(self.clouds):
            for j, c2 in enumerate(self.clouds):
                if i < j:
                    distance = np.linalg.norm(c1.mean - c2.mean)
                    if distance > eps:  
                        min_distance = min(min_distance, distance)

        # Se todos clusters forem muito próximos (possivelmente ruins)
        if min_distance == float('inf'):
            return 0.0

        # Cálculo final com proteção contra zero no denominador
        denominator = len(self.clouds) * max(min_distance, eps)
        return total / denominator


    def run(self, x):
        if self.k < 20 or self.k % 5000 == 0:
            print(f"[k={self.k}] x = {x}")

        self.k += 1   #"estou processando mais uma amostra"
        x = np.array(x)  # Garante que x seja um numpy array

        # Passo 1: Processamento das primeiras 2 amostras (mantido do original)
        if self.k == 1:
            self.clouds.append(DataCloud(x))
            self.classIndex.append(0)
            return

        if self.k == 2:
            self.clouds[0].updateDataCloud(x)
            self.classIndex.append(0)
            return

        # Passo 2: A partir da terceira amostra
        closest_cloud = None
        min_ecc = float('inf')
        threshold_factor = (self.m**2 + 1) / 3  # 🔹 Cálculo movido para evitar redundância 

        for i, cloud in enumerate(self.clouds):
            ecc = self.calculate_eccentricity(x, cloud)
            threshold = threshold_factor / cloud.n  # 🔹 Movido para dentro do loop para evitar cálculos repetidos
            
            if ecc <= threshold and ecc < min_ecc:
                closest_cloud = i
                min_ecc = ecc

        # Passo 3: Atualiza cloud existente (mais típica)
        if closest_cloud is not None:
            cloud = self.clouds[closest_cloud]
            
            n_old = cloud.n  # 🔹 Guarda o valor antigo de `n`
            n_new = n_old + 1  # Não incrementa `cloud.n` aqui!

            old_mean = cloud.mean  # 🔹 Armazena a média antes da atualização

            # Atualiza média (Eq. 4)
            cloud.mean = (n_old / n_new) * cloud.mean + (1 / n_new) * x

            # Atualiza variância com tratamento especial se for o segundo ponto da nuvem
            if n_old == 1:
                cloud.variance = np.linalg.norm(x - old_mean) ** 2
            else:
                cloud.variance = ((n_old - 1) / n_old) * cloud.variance + (1 / n_new) * np.linalg.norm(x - old_mean) ** 2
            
            cloud.variance = max(cloud.variance, 1e-6)  # Proteção contra variância zero
            cloud.n = n_new  # Só agora atualiza o contador de amostras da cloud

            self.classIndex.append(closest_cloud)

        else:
            # Nenhuma cloud típica → cria nova cloud
            self.clouds.append(DataCloud(x))
            self.classIndex.append(len(self.clouds) - 1)

            # 🔹 Fusão sob demanda (somente se nova cloud criada)
            self.merge_clouds()

            """
            # Novo critério de fallback baseado em distância ao centróide
            for i, cloud in enumerate(self.clouds):
                # Distância Euclidiana entre x e o centróide da cloud
                dist = np.linalg.norm(x - cloud.mean)
                
                # Critério: atualiza se a distância for pequena o suficiente
                if dist < 0.75:  #Ajuste este valor conforme necessário
                    cloud.updateDataCloud(x)
                    self.classIndex.append(i)
                    return # Nenhuma nova cloud foi criada, então NÃO funde
            
            # Chegamos aqui => nova cloud será criada
            self.clouds.append(DataCloud(x))
            self.classIndex.append(len(self.clouds) - 1)

            # 🔹 Fusão sob demanda: só se nova cloud foi criada
            self.merge_clouds()
            """

# %%
#Loop Loopinho
if __name__ == "__main__":
    import time

    # Carregar dados
    df = pd.read_csv('dados_rotulados.csv', sep=',')
    features = df[['tcp.flags.ack', 'tcp.flags.fin', 'tcp.flags.syn', 'tcp.flags.urg', 'tcp.time_delta']].values

    # Criar e executar AutoCloud
    ac = AutoCloud(m=3.3)

    start_time = time.time()  # 🔹 Inicia medição do tempo

    for i, x in enumerate(features[:140544]):  
        ac.run(x)

        if i % 100 == 0 and i > 0:  # 🔹 Evita exibir na iteração 0
            elapsed = time.time() - start_time
            estimated_total = (elapsed / i) * 50000
            remaining_time = estimated_total - elapsed

            print(f"Processadas {i} amostras, {len(ac.clouds)} clouds criadas")
            print(f"Qualidade atual: {ac.calculate_quality():.4f}")
            #print(f"Tempo estimado restante: {remaining_time:.2f}s")  # 🔹 Mostra tempo estimado

    # Testes adicionais
    print("\nTestes de consistência:")
    print(f"Total de amostras processadas: {len(ac.classIndex)}")
    print(f"Soma de amostras registradas nas clouds: {sum(cloud.n for cloud in ac.clouds)}")
    print(f"Frequência de clouds:\n{Counter(ac.classIndex)}")
    
    # Escolher as clouds mais populosas para análise
    cloud_counts = Counter(ac.classIndex)
    
    # Exibir estatísticas das clouds
    print("\nResultados finais:")
    print(f"Total de clouds: {len(ac.clouds)}")
    print(f"Métrica de qualidade: {ac.calculate_quality():.4f}")

    for i, cloud in enumerate(ac.clouds):
        num_amostras = cloud_counts.get(i, 0)
        print(f"\nCloud {i}:")
        print(f"  Núm. amostras: {cloud.n}")
        print(f"  Centróide: {cloud.mean}")
        print(f"  Variância: {cloud.variance:.4f}")
        print(f"  Amostras associadas: {num_amostras}")
# Out:
# [k=0] x = [0. 0. 0. 0. 0.]
# [k=1] x = [0. 0. 1. 0. 0.]
# [k=2] x = [0. 0. 1. 0. 0.]
# [k=3] x = [0. 0. 1. 0. 0.]
# [k=4] x = [0. 0. 1. 0. 0.]
# [k=5] x = [1. 0. 0. 0. 0.]
# [k=6] x = [1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 4.9702e-05]
# [k=7] x = [0. 0. 0. 0. 0.]
# [k=8] x = [0. 0. 0. 0. 0.]
# [k=9] x = [0. 0. 0. 0. 0.]
# [k=10] x = [0. 0. 0. 0. 0.]
# [k=11] x = [0. 0. 0. 0. 0.]
# [k=12] x = [0.         0.         1.         0.         1.00997385]
# [k=13] x = [0.        0.        1.        0.        1.0099721]
# [k=14] x = [1.         0.         0.         0.         0.99795841]
# [k=15] x = [1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 4.9389e-05]
# [k=16] x = [0. 0. 1. 0. 0.]
# [k=17] x = [0. 0. 1. 0. 0.]
# [k=18] x = [0. 0. 0. 0. 0.]
# [k=19] x = [0. 0. 0. 0. 0.]
# Processadas 100 amostras, 1 clouds criadas
# Qualidade atual: 0.0000
# Processadas 200 amostras, 1 clouds criadas
# Qualidade atual: 0.0000
# Processadas 300 amostras, 1 clouds criadas
# Qualidade atual: 0.0000
# Processadas 400 amostras, 1 clouds criadas
# Qualidade atual: 0.0000
# Processadas 500 amostras, 1 clouds criadas
# Qualidade atual: 0.0000
# Processadas 600 amostras, 2 clouds criadas
# Qualidade atual: 0.4210
# Processadas 700 amostras, 2 clouds criadas
# Qualidade atual: 0.4086
# Processadas 800 amostras, 2 clouds criadas
# Qualidade atual: 0.6716
# Processadas 900 amostras, 2 clouds criadas
# Qualidade atual: 1.0363
# Processadas 1000 amostras, 2 clouds criadas
# Qualidade atual: 0.8787
# Processadas 1100 amostras, 2 clouds criadas
# Qualidade atual: 0.7270
# Processadas 1200 amostras, 2 clouds criadas
# Qualidade atual: 0.5828
# Processadas 1300 amostras, 2 clouds criadas
# Qualidade atual: 0.5543
# Processadas 1400 amostras, 2 clouds criadas
# Qualidade atual: 0.5056
# Processadas 1500 amostras, 2 clouds criadas
# Qualidade atual: 0.4861
# Processadas 1600 amostras, 2 clouds criadas
# Qualidade atual: 0.4602
# Processadas 1700 amostras, 2 clouds criadas
# Qualidade atual: 0.4502
# Processadas 1800 amostras, 2 clouds criadas
# Qualidade atual: 0.4347
# Processadas 1900 amostras, 2 clouds criadas
# Qualidade atual: 0.4278
# Processadas 2000 amostras, 2 clouds criadas
# Qualidade atual: 0.4148
# Processadas 2100 amostras, 2 clouds criadas
# Qualidade atual: 0.4092
# Processadas 2200 amostras, 2 clouds criadas
# Qualidade atual: 0.4052
# Processadas 2300 amostras, 2 clouds criadas
# Qualidade atual: 0.4012
# Processadas 2400 amostras, 2 clouds criadas
# Qualidade atual: 0.3967
# Processadas 2500 amostras, 2 clouds criadas
# Qualidade atual: 0.4018
# Processadas 2600 amostras, 2 clouds criadas
# Qualidade atual: 0.4067
# Processadas 2700 amostras, 2 clouds criadas
# Qualidade atual: 0.4049
# Processadas 2800 amostras, 2 clouds criadas
# Qualidade atual: 0.4440
# Processadas 2900 amostras, 2 clouds criadas
# Qualidade atual: 0.4405
# Processadas 3000 amostras, 2 clouds criadas
# Qualidade atual: 0.4398
# Processadas 3100 amostras, 2 clouds criadas
# Qualidade atual: 0.4557
# Processadas 3200 amostras, 2 clouds criadas
# Qualidade atual: 0.4606
# Processadas 3300 amostras, 2 clouds criadas
# Qualidade atual: 0.4519
# Processadas 3400 amostras, 2 clouds criadas
# Qualidade atual: 0.4507
# Processadas 3500 amostras, 2 clouds criadas
# Qualidade atual: 0.4547
# Processadas 3600 amostras, 2 clouds criadas
# Qualidade atual: 0.4470
# Processadas 3700 amostras, 2 clouds criadas
# Qualidade atual: 0.4483
# Processadas 3800 amostras, 2 clouds criadas
# Qualidade atual: 0.4407
# Processadas 3900 amostras, 2 clouds criadas
# Qualidade atual: 0.4420
# Processadas 4000 amostras, 2 clouds criadas
# Qualidade atual: 0.4430
# Processadas 4100 amostras, 2 clouds criadas
# Qualidade atual: 0.4395
# Processadas 4200 amostras, 2 clouds criadas
# Qualidade atual: 0.4393
# Processadas 4300 amostras, 2 clouds criadas
# Qualidade atual: 0.4409
# Processadas 4400 amostras, 2 clouds criadas
# Qualidade atual: 0.4501
# Processadas 4500 amostras, 2 clouds criadas
# Qualidade atual: 0.4509
# Processadas 4600 amostras, 2 clouds criadas
# Qualidade atual: 0.4452
# Processadas 4700 amostras, 2 clouds criadas
# Qualidade atual: 0.4425
# Processadas 4800 amostras, 2 clouds criadas
# Qualidade atual: 0.4386
# Processadas 4900 amostras, 2 clouds criadas
# Qualidade atual: 0.4452
# [k=5000] x = [1.         0.         0.         0.         0.00201516]
# Processadas 5000 amostras, 2 clouds criadas
# Qualidade atual: 0.4577
# Processadas 5100 amostras, 2 clouds criadas
# Qualidade atual: 0.4567
# Processadas 5200 amostras, 2 clouds criadas
# Qualidade atual: 0.4552
# Processadas 5300 amostras, 2 clouds criadas
# Qualidade atual: 0.4527
# Processadas 5400 amostras, 2 clouds criadas
# Qualidade atual: 0.4515
# Processadas 5500 amostras, 2 clouds criadas
# Qualidade atual: 0.4464
# Processadas 5600 amostras, 2 clouds criadas
# Qualidade atual: 0.4452
# Processadas 5700 amostras, 2 clouds criadas
# Qualidade atual: 0.4445
# Processadas 5800 amostras, 2 clouds criadas
# Qualidade atual: 0.4412
# Processadas 5900 amostras, 2 clouds criadas
# Qualidade atual: 0.4404
# Processadas 6000 amostras, 2 clouds criadas
# Qualidade atual: 0.4393
# Processadas 6100 amostras, 2 clouds criadas
# Qualidade atual: 0.4392
# Processadas 6200 amostras, 2 clouds criadas
# Qualidade atual: 0.4382
# Processadas 6300 amostras, 2 clouds criadas
# Qualidade atual: 0.4372
# Processadas 6400 amostras, 2 clouds criadas
# Qualidade atual: 0.4329
# Processadas 6500 amostras, 2 clouds criadas
# Qualidade atual: 0.4321
# Processadas 6600 amostras, 2 clouds criadas
# Qualidade atual: 0.4292
# Processadas 6700 amostras, 2 clouds criadas
# Qualidade atual: 0.4284
# Processadas 6800 amostras, 2 clouds criadas
# Qualidade atual: 0.4284
# Processadas 6900 amostras, 2 clouds criadas
# Qualidade atual: 0.4277
# Processadas 7000 amostras, 2 clouds criadas
# Qualidade atual: 0.4238
# Processadas 7100 amostras, 2 clouds criadas
# Qualidade atual: 0.4230
# Processadas 7200 amostras, 2 clouds criadas
# Qualidade atual: 0.4204
# Processadas 7300 amostras, 2 clouds criadas
# Qualidade atual: 0.4197
# Processadas 7400 amostras, 2 clouds criadas
# Qualidade atual: 0.4210
# Processadas 7500 amostras, 2 clouds criadas
# Qualidade atual: 0.4204
# Processadas 7600 amostras, 2 clouds criadas
# Qualidade atual: 0.4197
# Processadas 7700 amostras, 2 clouds criadas
# Qualidade atual: 0.4190
# Processadas 7800 amostras, 2 clouds criadas
# Qualidade atual: 0.4184
# Processadas 7900 amostras, 2 clouds criadas
# Qualidade atual: 0.4204
# Processadas 8000 amostras, 2 clouds criadas
# Qualidade atual: 0.4198
# Processadas 8100 amostras, 2 clouds criadas
# Qualidade atual: 0.4164
# Processadas 8200 amostras, 2 clouds criadas
# Qualidade atual: 0.4158
# Processadas 8300 amostras, 2 clouds criadas
# Qualidade atual: 0.4152
# Processadas 8400 amostras, 2 clouds criadas
# Qualidade atual: 0.4130
# Processadas 8500 amostras, 2 clouds criadas
# Qualidade atual: 0.4125
# Processadas 8600 amostras, 2 clouds criadas
# Qualidade atual: 0.4140
# Processadas 8700 amostras, 2 clouds criadas
# Qualidade atual: 0.4134
# Processadas 8800 amostras, 2 clouds criadas
# Qualidade atual: 0.4120
# Processadas 8900 amostras, 2 clouds criadas
# Qualidade atual: 0.4112
# Processadas 9000 amostras, 2 clouds criadas
# Qualidade atual: 0.4107
# Processadas 9100 amostras, 2 clouds criadas
# Qualidade atual: 0.4076
# Processadas 9200 amostras, 2 clouds criadas
# Qualidade atual: 0.4053
# Processadas 9300 amostras, 2 clouds criadas
# Qualidade atual: 0.4049
# Processadas 9400 amostras, 2 clouds criadas
# Qualidade atual: 0.4064
# Processadas 9500 amostras, 2 clouds criadas
# Qualidade atual: 0.4059
# Processadas 9600 amostras, 2 clouds criadas
# Qualidade atual: 0.4050
# Processadas 9700 amostras, 2 clouds criadas
# Qualidade atual: 0.4045
# Processadas 9800 amostras, 2 clouds criadas
# Qualidade atual: 0.4041
# Processadas 9900 amostras, 2 clouds criadas
# Qualidade atual: 0.4035
# [k=10000] x = [1.         0.         0.         0.         0.00953613]
# Processadas 10000 amostras, 2 clouds criadas
# Qualidade atual: 0.4022
# Processadas 10100 amostras, 2 clouds criadas
# Qualidade atual: 0.4017
# Processadas 10200 amostras, 2 clouds criadas
# Qualidade atual: 0.3999
# Processadas 10300 amostras, 2 clouds criadas
# Qualidade atual: 0.3964
# Processadas 10400 amostras, 2 clouds criadas
# Qualidade atual: 0.3934
# Processadas 10500 amostras, 2 clouds criadas
# Qualidade atual: 0.3918
# Processadas 10600 amostras, 2 clouds criadas
# Qualidade atual: 0.3907
# Processadas 10700 amostras, 2 clouds criadas
# Qualidade atual: 0.3926
# Processadas 10800 amostras, 2 clouds criadas
# Qualidade atual: 0.3923
# Processadas 10900 amostras, 2 clouds criadas
# Qualidade atual: 0.3929
# Processadas 11000 amostras, 2 clouds criadas
# Qualidade atual: 0.3933
# Processadas 11100 amostras, 2 clouds criadas
# Qualidade atual: 0.3935
# Processadas 11200 amostras, 2 clouds criadas
# Qualidade atual: 0.3939
# Processadas 11300 amostras, 2 clouds criadas
# Qualidade atual: 0.3936
# Processadas 11400 amostras, 2 clouds criadas
# Qualidade atual: 0.3930
# Processadas 11500 amostras, 2 clouds criadas
# Qualidade atual: 0.3926
# Processadas 11600 amostras, 2 clouds criadas
# Qualidade atual: 0.3920
# Processadas 11700 amostras, 2 clouds criadas
# Qualidade atual: 0.3888
# Processadas 11800 amostras, 2 clouds criadas
# Qualidade atual: 0.3884
# Processadas 11900 amostras, 2 clouds criadas
# Qualidade atual: 0.3877
# Processadas 12000 amostras, 2 clouds criadas
# Qualidade atual: 0.4640
# Processadas 12100 amostras, 2 clouds criadas
# Qualidade atual: 0.7085
# Processadas 12200 amostras, 2 clouds criadas
# Qualidade atual: 0.8859
# Processadas 12300 amostras, 2 clouds criadas
# Qualidade atual: 0.8057
# Processadas 12400 amostras, 2 clouds criadas
# Qualidade atual: 0.8150
# Processadas 12500 amostras, 2 clouds criadas
# Qualidade atual: 0.7689
# Processadas 12600 amostras, 2 clouds criadas
# Qualidade atual: 0.7445
# Processadas 12700 amostras, 2 clouds criadas
# Qualidade atual: 0.7511
# Processadas 12800 amostras, 2 clouds criadas
# Qualidade atual: 0.6775
# Processadas 12900 amostras, 2 clouds criadas
# Qualidade atual: 0.6206
# Processadas 13000 amostras, 2 clouds criadas
# Qualidade atual: 0.6200
# Processadas 13100 amostras, 2 clouds criadas
# Qualidade atual: 0.5960
# Processadas 13200 amostras, 2 clouds criadas
# Qualidade atual: 0.5589
# Processadas 13300 amostras, 2 clouds criadas
# Qualidade atual: 0.5383
# Processadas 13400 amostras, 2 clouds criadas
# Qualidade atual: 0.5377
# Processadas 13500 amostras, 2 clouds criadas
# Qualidade atual: 0.5103
# Processadas 13600 amostras, 2 clouds criadas
# Qualidade atual: 0.0162
# Processadas 13700 amostras, 4 clouds criadas
# Qualidade atual: 0.0344
# Processadas 13800 amostras, 4 clouds criadas
# Qualidade atual: 0.0342
# Processadas 13900 amostras, 4 clouds criadas
# Qualidade atual: 0.1553
# Processadas 14000 amostras, 4 clouds criadas
# Qualidade atual: 0.0208
# Processadas 14100 amostras, 4 clouds criadas
# Qualidade atual: 0.0206
# Processadas 14200 amostras, 4 clouds criadas
# Qualidade atual: 6.1133
# Processadas 14300 amostras, 4 clouds criadas
# Qualidade atual: 6.1128
# Processadas 14400 amostras, 4 clouds criadas
# Qualidade atual: 5.3709
# Processadas 14500 amostras, 4 clouds criadas
# Qualidade atual: 2.2739
# Processadas 14600 amostras, 4 clouds criadas
# Qualidade atual: 2.2738
# Processadas 14700 amostras, 4 clouds criadas
# Qualidade atual: 2.0347
# Processadas 14800 amostras, 4 clouds criadas
# Qualidade atual: 2.4089
# Processadas 14900 amostras, 4 clouds criadas
# Qualidade atual: 2.6311
# [k=15000] x = [1.         0.         0.         0.         0.00183052]
# Processadas 15000 amostras, 4 clouds criadas
# Qualidade atual: 2.6309
# Processadas 15100 amostras, 4 clouds criadas
# Qualidade atual: 3.2421
# Processadas 15200 amostras, 4 clouds criadas
# Qualidade atual: 3.1861
# Processadas 15300 amostras, 4 clouds criadas
# Qualidade atual: 3.1858
# Processadas 15400 amostras, 4 clouds criadas
# Qualidade atual: 2.9712
# Processadas 15500 amostras, 4 clouds criadas
# Qualidade atual: 3.0732
# Processadas 15600 amostras, 4 clouds criadas
# Qualidade atual: 3.1490
# Processadas 15700 amostras, 4 clouds criadas
# Qualidade atual: 0.0224
# Processadas 15800 amostras, 4 clouds criadas
# Qualidade atual: 0.0224
# Processadas 15900 amostras, 4 clouds criadas
# Qualidade atual: 0.0223
# Processadas 16000 amostras, 4 clouds criadas
# Qualidade atual: 0.0222
# Processadas 16100 amostras, 4 clouds criadas
# Qualidade atual: 0.0220
# Processadas 16200 amostras, 5 clouds criadas
# Qualidade atual: 0.0289
# Processadas 16300 amostras, 5 clouds criadas
# Qualidade atual: 0.0288
# Processadas 16400 amostras, 7 clouds criadas
# Qualidade atual: 1.6302
# Processadas 16500 amostras, 6 clouds criadas
# Qualidade atual: 0.0240
# Processadas 16600 amostras, 6 clouds criadas
# Qualidade atual: 0.0239
# Processadas 16700 amostras, 6 clouds criadas
# Qualidade atual: 0.0238
# Processadas 16800 amostras, 6 clouds criadas
# Qualidade atual: 0.0236
# Processadas 16900 amostras, 6 clouds criadas
# Qualidade atual: 0.0235
# Processadas 17000 amostras, 6 clouds criadas
# Qualidade atual: 0.0234
# Processadas 17100 amostras, 6 clouds criadas
# Qualidade atual: 0.0233
# Processadas 17200 amostras, 6 clouds criadas
# Qualidade atual: 0.0232
# Processadas 17300 amostras, 6 clouds criadas
# Qualidade atual: 0.0231
# Processadas 17400 amostras, 6 clouds criadas
# Qualidade atual: 0.0230
# Processadas 17500 amostras, 6 clouds criadas
# Qualidade atual: 0.0229
# Processadas 17600 amostras, 6 clouds criadas
# Qualidade atual: 0.0228
# Processadas 17700 amostras, 6 clouds criadas
# Qualidade atual: 0.0226
# Processadas 17800 amostras, 6 clouds criadas
# Qualidade atual: 0.0225
# Processadas 17900 amostras, 6 clouds criadas
# Qualidade atual: 0.0224
# Processadas 18000 amostras, 6 clouds criadas
# Qualidade atual: 0.0224
# Processadas 18100 amostras, 6 clouds criadas
# Qualidade atual: 0.0223
# Processadas 18200 amostras, 6 clouds criadas
# Qualidade atual: 0.0221
# Processadas 18300 amostras, 6 clouds criadas
# Qualidade atual: 0.0220
# Processadas 18400 amostras, 6 clouds criadas
# Qualidade atual: 0.0220
# Processadas 18500 amostras, 6 clouds criadas
# Qualidade atual: 0.0218
# Processadas 18600 amostras, 6 clouds criadas
# Qualidade atual: 0.0217
# Processadas 18700 amostras, 6 clouds criadas
# Qualidade atual: 0.0216
# Processadas 18800 amostras, 6 clouds criadas
# Qualidade atual: 0.0215
# Processadas 18900 amostras, 6 clouds criadas
# Qualidade atual: 0.0214
# Processadas 19000 amostras, 6 clouds criadas
# Qualidade atual: 0.0213
# Processadas 19100 amostras, 6 clouds criadas
# Qualidade atual: 0.0212
# Processadas 19200 amostras, 6 clouds criadas
# Qualidade atual: 0.0212
# Processadas 19300 amostras, 6 clouds criadas
# Qualidade atual: 0.0211
# Processadas 19400 amostras, 6 clouds criadas
# Qualidade atual: 0.0210
# Processadas 19500 amostras, 6 clouds criadas
# Qualidade atual: 0.0209
# Processadas 19600 amostras, 6 clouds criadas
# Qualidade atual: 0.0208
# Processadas 19700 amostras, 6 clouds criadas
# Qualidade atual: 0.0207
# Processadas 19800 amostras, 6 clouds criadas
# Qualidade atual: 0.0206
# Processadas 19900 amostras, 6 clouds criadas
# Qualidade atual: 0.0205
# [k=20000] x = [1.        0.        0.        0.        0.0016893]
# Processadas 20000 amostras, 6 clouds criadas
# Qualidade atual: 0.0205
# Processadas 20100 amostras, 6 clouds criadas
# Qualidade atual: 0.0204
# Processadas 20200 amostras, 6 clouds criadas
# Qualidade atual: 0.0203
# Processadas 20300 amostras, 6 clouds criadas
# Qualidade atual: 0.0202
# Processadas 20400 amostras, 6 clouds criadas
# Qualidade atual: 0.0202
# Processadas 20500 amostras, 6 clouds criadas
# Qualidade atual: 0.0201
# Processadas 20600 amostras, 6 clouds criadas
# Qualidade atual: 0.0200
# Processadas 20700 amostras, 6 clouds criadas
# Qualidade atual: 0.0199
# Processadas 20800 amostras, 6 clouds criadas
# Qualidade atual: 0.0198
# Processadas 20900 amostras, 6 clouds criadas
# Qualidade atual: 0.0198
# Processadas 21000 amostras, 7 clouds criadas
# Qualidade atual: 0.2647
# Processadas 21100 amostras, 7 clouds criadas
# Qualidade atual: 0.2635
# Processadas 21200 amostras, 7 clouds criadas
# Qualidade atual: 0.3903
# Processadas 21300 amostras, 7 clouds criadas
# Qualidade atual: 0.3998
# Processadas 21400 amostras, 7 clouds criadas
# Qualidade atual: 0.3997
# Processadas 21500 amostras, 7 clouds criadas
# Qualidade atual: 0.3395
# Processadas 21600 amostras, 7 clouds criadas
# Qualidade atual: 0.2826
# Processadas 21700 amostras, 7 clouds criadas
# Qualidade atual: 0.2825
# Processadas 21800 amostras, 7 clouds criadas
# Qualidade atual: 0.2167
# Processadas 21900 amostras, 7 clouds criadas
# Qualidade atual: 0.1998
# Processadas 22000 amostras, 7 clouds criadas
# Qualidade atual: 0.1927
# Processadas 22100 amostras, 7 clouds criadas
# Qualidade atual: 0.1926
# Processadas 22200 amostras, 7 clouds criadas
# Qualidade atual: 0.1797
# Processadas 22300 amostras, 7 clouds criadas
# Qualidade atual: 0.1796
# Processadas 22400 amostras, 7 clouds criadas
# Qualidade atual: 0.1795
# Processadas 22500 amostras, 7 clouds criadas
# Qualidade atual: 0.1632
# Processadas 22600 amostras, 7 clouds criadas
# Qualidade atual: 0.1631
# Processadas 22700 amostras, 7 clouds criadas
# Qualidade atual: 0.1538
# Processadas 22800 amostras, 7 clouds criadas
# Qualidade atual: 0.1349
# Processadas 22900 amostras, 7 clouds criadas
# Qualidade atual: 0.0318
# Processadas 23000 amostras, 7 clouds criadas
# Qualidade atual: 0.0317
# Processadas 23100 amostras, 7 clouds criadas
# Qualidade atual: 0.3457
# Processadas 23200 amostras, 7 clouds criadas
# Qualidade atual: 0.3154
# Processadas 23300 amostras, 7 clouds criadas
# Qualidade atual: 0.2550
# Processadas 23400 amostras, 7 clouds criadas
# Qualidade atual: 0.2549
# Processadas 23500 amostras, 7 clouds criadas
# Qualidade atual: 0.2434
# Processadas 23600 amostras, 7 clouds criadas
# Qualidade atual: 0.2487
# Processadas 23700 amostras, 7 clouds criadas
# Qualidade atual: 0.2486
# Processadas 23800 amostras, 7 clouds criadas
# Qualidade atual: 0.2207
# Processadas 23900 amostras, 7 clouds criadas
# Qualidade atual: 0.2206
# Processadas 24000 amostras, 7 clouds criadas
# Qualidade atual: 0.2123
# Processadas 24100 amostras, 7 clouds criadas
# Qualidade atual: 0.2045
# Processadas 24200 amostras, 7 clouds criadas
# Qualidade atual: 0.1972
# Processadas 24300 amostras, 7 clouds criadas
# Qualidade atual: 0.1840
# Processadas 24400 amostras, 7 clouds criadas
# Qualidade atual: 0.1724
# Processadas 24500 amostras, 7 clouds criadas
# Qualidade atual: 0.1842
# Processadas 24600 amostras, 7 clouds criadas
# Qualidade atual: 0.1789
# Processadas 24700 amostras, 7 clouds criadas
# Qualidade atual: 0.1788
# Processadas 24800 amostras, 7 clouds criadas
# Qualidade atual: 0.1739
# Processadas 24900 amostras, 7 clouds criadas
# Qualidade atual: 0.1566
# [k=25000] x = [1.         0.         0.         0.         0.01280036]
# Processadas 25000 amostras, 7 clouds criadas
# Qualidade atual: 0.1527
# Processadas 25100 amostras, 7 clouds criadas
# Qualidade atual: 0.1526
# Processadas 25200 amostras, 7 clouds criadas
# Qualidade atual: 0.1341
# Processadas 25300 amostras, 7 clouds criadas
# Qualidade atual: 0.1306
# Processadas 25400 amostras, 7 clouds criadas
# Qualidade atual: 0.1305
# Processadas 25500 amostras, 7 clouds criadas
# Qualidade atual: 0.1288
# Processadas 25600 amostras, 7 clouds criadas
# Qualidade atual: 0.1255
# Processadas 25700 amostras, 7 clouds criadas
# Qualidade atual: 0.1254
# Processadas 25800 amostras, 7 clouds criadas
# Qualidade atual: 0.1238
# Processadas 25900 amostras, 7 clouds criadas
# Qualidade atual: 0.1237
# Processadas 26000 amostras, 7 clouds criadas
# Qualidade atual: 0.1207
# Processadas 26100 amostras, 7 clouds criadas
# Qualidade atual: 0.1192
# Processadas 26200 amostras, 7 clouds criadas
# Qualidade atual: 0.1192
# Processadas 26300 amostras, 7 clouds criadas
# Qualidade atual: 0.1151
# Processadas 26400 amostras, 7 clouds criadas
# Qualidade atual: 0.1150
# Processadas 26500 amostras, 7 clouds criadas
# Qualidade atual: 0.1100
# Processadas 26600 amostras, 7 clouds criadas
# Qualidade atual: 0.1076
# Processadas 26700 amostras, 7 clouds criadas
# Qualidade atual: 0.1092
# Processadas 26800 amostras, 7 clouds criadas
# Qualidade atual: 0.1061
# Processadas 26900 amostras, 7 clouds criadas
# Qualidade atual: 0.1050
# Processadas 27000 amostras, 7 clouds criadas
# Qualidade atual: 0.1012
# Processadas 27100 amostras, 7 clouds criadas
# Qualidade atual: 0.0977
# Processadas 27200 amostras, 7 clouds criadas
# Qualidade atual: 0.0968
# Processadas 27300 amostras, 7 clouds criadas
# Qualidade atual: 0.0984
# Processadas 27400 amostras, 7 clouds criadas
# Qualidade atual: 0.0983
# Processadas 27500 amostras, 7 clouds criadas
# Qualidade atual: 0.0982
# Processadas 27600 amostras, 7 clouds criadas
# Qualidade atual: 0.0982
# Processadas 27700 amostras, 7 clouds criadas
# Qualidade atual: 0.0951
# Processadas 27800 amostras, 7 clouds criadas
# Qualidade atual: 0.0936
# Processadas 27900 amostras, 7 clouds criadas
# Qualidade atual: 0.0935
# Processadas 28000 amostras, 7 clouds criadas
# Qualidade atual: 0.0934
# Processadas 28100 amostras, 7 clouds criadas
# Qualidade atual: 0.0934
# Processadas 28200 amostras, 7 clouds criadas
# Qualidade atual: 0.0933
# Processadas 28300 amostras, 7 clouds criadas
# Qualidade atual: 0.0932
# Processadas 28400 amostras, 7 clouds criadas
# Qualidade atual: 0.0932
# Processadas 28500 amostras, 7 clouds criadas
# Qualidade atual: 0.0931
# Processadas 28600 amostras, 7 clouds criadas
# Qualidade atual: 0.0897
# Processadas 28700 amostras, 7 clouds criadas
# Qualidade atual: 0.0896
# Processadas 28800 amostras, 7 clouds criadas
# Qualidade atual: 0.0889
# Processadas 28900 amostras, 7 clouds criadas
# Qualidade atual: 0.0888
# Processadas 29000 amostras, 7 clouds criadas
# Qualidade atual: 0.0888
# Processadas 29100 amostras, 7 clouds criadas
# Qualidade atual: 0.0887
# Processadas 29200 amostras, 7 clouds criadas
# Qualidade atual: 0.0886
# Processadas 29300 amostras, 7 clouds criadas
# Qualidade atual: 0.0873
# Processadas 29400 amostras, 7 clouds criadas
# Qualidade atual: 0.0873
# Processadas 29500 amostras, 7 clouds criadas
# Qualidade atual: 0.0872
# Processadas 29600 amostras, 7 clouds criadas
# Qualidade atual: 0.0859
# Processadas 29700 amostras, 7 clouds criadas
# Qualidade atual: 0.0859
# Processadas 29800 amostras, 7 clouds criadas
# Qualidade atual: 0.0858
# Processadas 29900 amostras, 7 clouds criadas
# Qualidade atual: 0.0852
# [k=30000] x = [1.         0.         0.         0.         0.01019569]
# Processadas 30000 amostras, 7 clouds criadas
# Qualidade atual: 0.0851
# Processadas 30100 amostras, 7 clouds criadas
# Qualidade atual: 0.0839
# Processadas 30200 amostras, 7 clouds criadas
# Qualidade atual: 0.0833
# Processadas 30300 amostras, 7 clouds criadas
# Qualidade atual: 0.0827
# Processadas 30400 amostras, 7 clouds criadas
# Qualidade atual: 0.0821
# Processadas 30500 amostras, 7 clouds criadas
# Qualidade atual: 0.0815
# Processadas 30600 amostras, 7 clouds criadas
# Qualidade atual: 0.0814
# Processadas 30700 amostras, 7 clouds criadas
# Qualidade atual: 0.0814
# Processadas 30800 amostras, 6 clouds criadas
# Qualidade atual: 0.0148
# Processadas 30900 amostras, 6 clouds criadas
# Qualidade atual: 0.0148
# Processadas 31000 amostras, 7 clouds criadas
# Qualidade atual: 0.4582
# Processadas 31100 amostras, 7 clouds criadas
# Qualidade atual: 0.4577
# Processadas 31200 amostras, 7 clouds criadas
# Qualidade atual: 0.4564
# Processadas 31300 amostras, 7 clouds criadas
# Qualidade atual: 0.4551
# Processadas 31400 amostras, 7 clouds criadas
# Qualidade atual: 0.4540
# Processadas 31500 amostras, 7 clouds criadas
# Qualidade atual: 0.4532
# Processadas 31600 amostras, 7 clouds criadas
# Qualidade atual: 0.4523
# Processadas 31700 amostras, 7 clouds criadas
# Qualidade atual: 0.4508
# Processadas 31800 amostras, 7 clouds criadas
# Qualidade atual: 0.4494
# Processadas 31900 amostras, 7 clouds criadas
# Qualidade atual: 0.4487
# Processadas 32000 amostras, 7 clouds criadas
# Qualidade atual: 0.4487
# Processadas 32100 amostras, 7 clouds criadas
# Qualidade atual: 0.4473
# Processadas 32200 amostras, 7 clouds criadas
# Qualidade atual: 0.4459
# Processadas 32300 amostras, 7 clouds criadas
# Qualidade atual: 0.4447
# Processadas 32400 amostras, 7 clouds criadas
# Qualidade atual: 0.4434
# Processadas 32500 amostras, 7 clouds criadas
# Qualidade atual: 0.4422
# Processadas 32600 amostras, 7 clouds criadas
# Qualidade atual: 0.4374
# Processadas 32700 amostras, 7 clouds criadas
# Qualidade atual: 0.4362
# Processadas 32800 amostras, 7 clouds criadas
# Qualidade atual: 0.4362
# Processadas 32900 amostras, 7 clouds criadas
# Qualidade atual: 0.4352
# Processadas 33000 amostras, 7 clouds criadas
# Qualidade atual: 0.4341
# Processadas 33100 amostras, 7 clouds criadas
# Qualidade atual: 0.4330
# Processadas 33200 amostras, 7 clouds criadas
# Qualidade atual: 0.4345
# Processadas 33300 amostras, 7 clouds criadas
# Qualidade atual: 0.4337
# Processadas 33400 amostras, 7 clouds criadas
# Qualidade atual: 0.4307
# Processadas 33500 amostras, 7 clouds criadas
# Qualidade atual: 0.4300
# Processadas 33600 amostras, 7 clouds criadas
# Qualidade atual: 0.4300
# Processadas 33700 amostras, 7 clouds criadas
# Qualidade atual: 0.4298
# Processadas 33800 amostras, 7 clouds criadas
# Qualidade atual: 0.4267
# Processadas 33900 amostras, 7 clouds criadas
# Qualidade atual: 0.4256
# Processadas 34000 amostras, 7 clouds criadas
# Qualidade atual: 0.4229
# Processadas 34100 amostras, 7 clouds criadas
# Qualidade atual: 0.4227
# Processadas 34200 amostras, 7 clouds criadas
# Qualidade atual: 0.4173
# Processadas 34300 amostras, 7 clouds criadas
# Qualidade atual: 0.4162
# Processadas 34400 amostras, 7 clouds criadas
# Qualidade atual: 0.4159
# Processadas 34500 amostras, 7 clouds criadas
# Qualidade atual: 0.4147
# Processadas 34600 amostras, 7 clouds criadas
# Qualidade atual: 0.4137
# Processadas 34700 amostras, 7 clouds criadas
# Qualidade atual: 0.4126
# Processadas 34800 amostras, 8 clouds criadas
# Qualidade atual: 0.3902
# Processadas 34900 amostras, 7 clouds criadas
# Qualidade atual: 0.4116
# [k=35000] x = [1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.2733e-04]
# Processadas 35000 amostras, 7 clouds criadas
# Qualidade atual: 0.4108
# Processadas 35100 amostras, 7 clouds criadas
# Qualidade atual: 0.4101
# Processadas 35200 amostras, 7 clouds criadas
# Qualidade atual: 0.4092
# Processadas 35300 amostras, 7 clouds criadas
# Qualidade atual: 0.4084
# Processadas 35400 amostras, 7 clouds criadas
# Qualidade atual: 0.4073
# Processadas 35500 amostras, 7 clouds criadas
# Qualidade atual: 0.4071
# Processadas 35600 amostras, 7 clouds criadas
# Qualidade atual: 0.4066
# Processadas 35700 amostras, 7 clouds criadas
# Qualidade atual: 0.4055
# Processadas 35800 amostras, 7 clouds criadas
# Qualidade atual: 0.4035
# Processadas 35900 amostras, 7 clouds criadas
# Qualidade atual: 0.4045
# Processadas 36000 amostras, 7 clouds criadas
# Qualidade atual: 0.4045
# Processadas 36100 amostras, 7 clouds criadas
# Qualidade atual: 0.4024
# Processadas 36200 amostras, 7 clouds criadas
# Qualidade atual: 0.4015
# Processadas 36300 amostras, 7 clouds criadas
# Qualidade atual: 0.4005
# Processadas 36400 amostras, 7 clouds criadas
# Qualidade atual: 0.3998
# Processadas 36500 amostras, 7 clouds criadas
# Qualidade atual: 0.3988
# Processadas 36600 amostras, 7 clouds criadas
# Qualidade atual: 0.3980
# Processadas 36700 amostras, 7 clouds criadas
# Qualidade atual: 0.3971
# Processadas 36800 amostras, 7 clouds criadas
# Qualidade atual: 0.3964
# Processadas 36900 amostras, 7 clouds criadas
# Qualidade atual: 0.3954
# Processadas 37000 amostras, 7 clouds criadas
# Qualidade atual: 0.3946
# Processadas 37100 amostras, 7 clouds criadas
# Qualidade atual: 0.3935
# Processadas 37200 amostras, 7 clouds criadas
# Qualidade atual: 0.3926
# Processadas 37300 amostras, 7 clouds criadas
# Qualidade atual: 0.3930
# Processadas 37400 amostras, 7 clouds criadas
# Qualidade atual: 0.3928
# Processadas 37500 amostras, 7 clouds criadas
# Qualidade atual: 0.3917
# Processadas 37600 amostras, 7 clouds criadas
# Qualidade atual: 0.3911
# Processadas 37700 amostras, 7 clouds criadas
# Qualidade atual: 0.3896
# Processadas 37800 amostras, 7 clouds criadas
# Qualidade atual: 0.3891
# Processadas 37900 amostras, 7 clouds criadas
# Qualidade atual: 0.3890
# Processadas 38000 amostras, 7 clouds criadas
# Qualidade atual: 0.3890
# Processadas 38100 amostras, 7 clouds criadas
# Qualidade atual: 0.3881
# Processadas 38200 amostras, 7 clouds criadas
# Qualidade atual: 0.3891
# Processadas 38300 amostras, 7 clouds criadas
# Qualidade atual: 0.3883
# Processadas 38400 amostras, 7 clouds criadas
# Qualidade atual: 0.3880
# Processadas 38500 amostras, 7 clouds criadas
# Qualidade atual: 0.3871
# Processadas 38600 amostras, 7 clouds criadas
# Qualidade atual: 0.3861
# Processadas 38700 amostras, 7 clouds criadas
# Qualidade atual: 0.3880
# Processadas 38800 amostras, 7 clouds criadas
# Qualidade atual: 0.3872
# Processadas 38900 amostras, 8 clouds criadas
# Qualidade atual: 0.3379
# Processadas 39000 amostras, 8 clouds criadas
# Qualidade atual: 0.3391
# Processadas 39100 amostras, 8 clouds criadas
# Qualidade atual: 0.3382
# Processadas 39200 amostras, 8 clouds criadas
# Qualidade atual: 0.3375
# Processadas 39300 amostras, 8 clouds criadas
# Qualidade atual: 0.3366
# Processadas 39400 amostras, 8 clouds criadas
# Qualidade atual: 0.3358
# Processadas 39500 amostras, 8 clouds criadas
# Qualidade atual: 0.3359
# Processadas 39600 amostras, 8 clouds criadas
# Qualidade atual: 0.3345
# Processadas 39700 amostras, 8 clouds criadas
# Qualidade atual: 0.3337
# Processadas 39800 amostras, 8 clouds criadas
# Qualidade atual: 0.3330
# Processadas 39900 amostras, 8 clouds criadas
# Qualidade atual: 0.3322
# [k=40000] x = [1.         0.         0.         0.         0.00894423]
# Processadas 40000 amostras, 8 clouds criadas
# Qualidade atual: 0.3318
# Processadas 40100 amostras, 8 clouds criadas
# Qualidade atual: 0.3309
# Processadas 40200 amostras, 8 clouds criadas
# Qualidade atual: 0.3303
# Processadas 40300 amostras, 8 clouds criadas
# Qualidade atual: 0.3295
# Processadas 40400 amostras, 8 clouds criadas
# Qualidade atual: 0.3283
# Processadas 40500 amostras, 8 clouds criadas
# Qualidade atual: 0.3272
# Processadas 40600 amostras, 8 clouds criadas
# Qualidade atual: 0.3259
# Processadas 40700 amostras, 8 clouds criadas
# Qualidade atual: 0.3243
# Processadas 40800 amostras, 8 clouds criadas
# Qualidade atual: 0.3236
# Processadas 40900 amostras, 8 clouds criadas
# Qualidade atual: 0.3224
# Processadas 41000 amostras, 8 clouds criadas
# Qualidade atual: 0.3220
# Processadas 41100 amostras, 8 clouds criadas
# Qualidade atual: 0.3212
# Processadas 41200 amostras, 8 clouds criadas
# Qualidade atual: 0.3211
# Processadas 41300 amostras, 8 clouds criadas
# Qualidade atual: 0.3203
# Processadas 41400 amostras, 8 clouds criadas
# Qualidade atual: 0.3195
# Processadas 41500 amostras, 8 clouds criadas
# Qualidade atual: 0.3189
# Processadas 41600 amostras, 8 clouds criadas
# Qualidade atual: 0.3182
# Processadas 41700 amostras, 8 clouds criadas
# Qualidade atual: 0.3174
# Processadas 41800 amostras, 8 clouds criadas
# Qualidade atual: 0.3173
# Processadas 41900 amostras, 8 clouds criadas
# Qualidade atual: 0.3165
# Processadas 42000 amostras, 8 clouds criadas
# Qualidade atual: 0.3158
# Processadas 42100 amostras, 8 clouds criadas
# Qualidade atual: 0.3151
# Processadas 42200 amostras, 8 clouds criadas
# Qualidade atual: 0.3144
# Processadas 42300 amostras, 8 clouds criadas
# Qualidade atual: 0.3137
# Processadas 42400 amostras, 8 clouds criadas
# Qualidade atual: 0.3130
# Processadas 42500 amostras, 8 clouds criadas
# Qualidade atual: 0.3118
# Processadas 42600 amostras, 8 clouds criadas
# Qualidade atual: 0.3111
# Processadas 42700 amostras, 8 clouds criadas
# Qualidade atual: 0.3103
# Processadas 42800 amostras, 8 clouds criadas
# Qualidade atual: 0.3099
# Processadas 42900 amostras, 8 clouds criadas
# Qualidade atual: 0.3092
# Processadas 43000 amostras, 8 clouds criadas
# Qualidade atual: 0.3080
# Processadas 43100 amostras, 8 clouds criadas
# Qualidade atual: 0.3073
# Processadas 43200 amostras, 8 clouds criadas
# Qualidade atual: 0.3060
# Processadas 43300 amostras, 8 clouds criadas
# Qualidade atual: 0.3053
# Processadas 43400 amostras, 8 clouds criadas
# Qualidade atual: 0.3047
# Processadas 43500 amostras, 8 clouds criadas
# Qualidade atual: 0.3040
# Processadas 43600 amostras, 8 clouds criadas
# Qualidade atual: 0.3033
# Processadas 43700 amostras, 9 clouds criadas
# Qualidade atual: 0.2691
# Processadas 43800 amostras, 9 clouds criadas
# Qualidade atual: 0.2681
# Processadas 43900 amostras, 9 clouds criadas
# Qualidade atual: 1.3918
# Processadas 44000 amostras, 9 clouds criadas
# Qualidade atual: 2.4407
# Processadas 44100 amostras, 9 clouds criadas
# Qualidade atual: 2.5403
# Processadas 44200 amostras, 9 clouds criadas
# Qualidade atual: 3.0371
# Processadas 44300 amostras, 9 clouds criadas
# Qualidade atual: 3.2342
# Processadas 44400 amostras, 9 clouds criadas
# Qualidade atual: 3.2377
# Processadas 44500 amostras, 9 clouds criadas
# Qualidade atual: 3.2362
# Processadas 44600 amostras, 9 clouds criadas
# Qualidade atual: 3.3132
# Processadas 44700 amostras, 9 clouds criadas
# Qualidade atual: 3.3157
# Processadas 44800 amostras, 9 clouds criadas
# Qualidade atual: 3.3152
# Processadas 44900 amostras, 9 clouds criadas
# Qualidade atual: 3.3365
# [k=45000] x = [1.         0.         0.         0.         0.01075561]
# Processadas 45000 amostras, 9 clouds criadas
# Qualidade atual: 3.3389
# Processadas 45100 amostras, 9 clouds criadas
# Qualidade atual: 3.3373
# Processadas 45200 amostras, 9 clouds criadas
# Qualidade atual: 3.3258
# Processadas 45300 amostras, 9 clouds criadas
# Qualidade atual: 3.3252
# Processadas 45400 amostras, 9 clouds criadas
# Qualidade atual: 3.3201
# Processadas 45500 amostras, 9 clouds criadas
# Qualidade atual: 3.0068
# Processadas 45600 amostras, 9 clouds criadas
# Qualidade atual: 2.8908
# Processadas 45700 amostras, 9 clouds criadas
# Qualidade atual: 0.2639
# Processadas 45800 amostras, 9 clouds criadas
# Qualidade atual: 0.2633
# Processadas 45900 amostras, 9 clouds criadas
# Qualidade atual: 0.2628
# Processadas 46000 amostras, 9 clouds criadas
# Qualidade atual: 0.2622
# Processadas 46100 amostras, 9 clouds criadas
# Qualidade atual: 0.2618
# Processadas 46200 amostras, 9 clouds criadas
# Qualidade atual: 0.2613
# Processadas 46300 amostras, 9 clouds criadas
# Qualidade atual: 0.2610
# Processadas 46400 amostras, 3 clouds criadas
# Qualidade atual: 0.9008
# Processadas 46500 amostras, 3 clouds criadas
# Qualidade atual: 0.8934
# Processadas 46600 amostras, 3 clouds criadas
# Qualidade atual: 0.8745
# Processadas 46700 amostras, 3 clouds criadas
# Qualidade atual: 0.8610
# Processadas 46800 amostras, 3 clouds criadas
# Qualidade atual: 0.8432
# Processadas 46900 amostras, 3 clouds criadas
# Qualidade atual: 0.8346
# Processadas 47000 amostras, 3 clouds criadas
# Qualidade atual: 1.2178
# Processadas 47100 amostras, 3 clouds criadas
# Qualidade atual: 1.0605
# Processadas 47200 amostras, 3 clouds criadas
# Qualidade atual: 0.7074
# Processadas 47300 amostras, 3 clouds criadas
# Qualidade atual: 20.7559
# Processadas 47400 amostras, 3 clouds criadas
# Qualidade atual: 5.7671
# Processadas 47500 amostras, 3 clouds criadas
# Qualidade atual: 2.4169
# Processadas 47600 amostras, 3 clouds criadas
# Qualidade atual: 1.7195
# Processadas 47700 amostras, 3 clouds criadas
# Qualidade atual: 49.3715
# Processadas 47800 amostras, 3 clouds criadas
# Qualidade atual: 37.4475
# Processadas 47900 amostras, 3 clouds criadas
# Qualidade atual: 33.0966
# Processadas 48000 amostras, 3 clouds criadas
# Qualidade atual: 11.4325
# Processadas 48100 amostras, 3 clouds criadas
# Qualidade atual: 5.3167
# Processadas 48200 amostras, 3 clouds criadas
# Qualidade atual: 9.8152
# Processadas 48300 amostras, 3 clouds criadas
# Qualidade atual: 12.3574
# Processadas 48400 amostras, 3 clouds criadas
# Qualidade atual: 16.4722
# Processadas 48500 amostras, 3 clouds criadas
# Qualidade atual: 12.5389
# Processadas 48600 amostras, 3 clouds criadas
# Qualidade atual: 6.0947
# Processadas 48700 amostras, 3 clouds criadas
# Qualidade atual: 2.0254
# Processadas 48800 amostras, 3 clouds criadas
# Qualidade atual: 1.6220
# Processadas 48900 amostras, 3 clouds criadas
# Qualidade atual: 1.2384
# Processadas 49000 amostras, 3 clouds criadas
# Qualidade atual: 1.0866
# Processadas 49100 amostras, 3 clouds criadas
# Qualidade atual: 0.9658
# Processadas 49200 amostras, 3 clouds criadas
# Qualidade atual: 0.8640
# Processadas 49300 amostras, 3 clouds criadas
# Qualidade atual: 0.8444
# Processadas 49400 amostras, 2 clouds criadas
# Qualidade atual: 28.7741
# Processadas 49500 amostras, 2 clouds criadas
# Qualidade atual: 22.9969
# Processadas 49600 amostras, 2 clouds criadas
# Qualidade atual: 17.5851
# Processadas 49700 amostras, 2 clouds criadas
# Qualidade atual: 11.3088
# Processadas 49800 amostras, 2 clouds criadas
# Qualidade atual: 8.4116
# Processadas 49900 amostras, 2 clouds criadas
# Qualidade atual: 7.0702
# [k=50000] x = [1.         0.         0.         0.         0.00517569]
# Processadas 50000 amostras, 2 clouds criadas
# Qualidade atual: 6.5605
# Processadas 50100 amostras, 2 clouds criadas
# Qualidade atual: 6.0899
# Processadas 50200 amostras, 2 clouds criadas
# Qualidade atual: 5.9275
# Processadas 50300 amostras, 2 clouds criadas
# Qualidade atual: 5.6453
# Processadas 50400 amostras, 2 clouds criadas
# Qualidade atual: 5.4873
# Processadas 50500 amostras, 2 clouds criadas
# Qualidade atual: 5.3672
# Processadas 50600 amostras, 2 clouds criadas
# Qualidade atual: 5.2614
# Processadas 50700 amostras, 2 clouds criadas
# Qualidade atual: 5.1587
# Processadas 50800 amostras, 2 clouds criadas
# Qualidade atual: 5.0590
# Processadas 50900 amostras, 2 clouds criadas
# Qualidade atual: 4.8791
# Processadas 51000 amostras, 2 clouds criadas
# Qualidade atual: 4.7885
# Processadas 51100 amostras, 2 clouds criadas
# Qualidade atual: 4.7006
# Processadas 51200 amostras, 2 clouds criadas
# Qualidade atual: 4.6154
# Processadas 51300 amostras, 2 clouds criadas
# Qualidade atual: 4.5328
# Processadas 51400 amostras, 2 clouds criadas
# Qualidade atual: 4.4526
# Processadas 51500 amostras, 2 clouds criadas
# Qualidade atual: 4.3749
# Processadas 51600 amostras, 2 clouds criadas
# Qualidade atual: 4.2995
# Processadas 51700 amostras, 2 clouds criadas
# Qualidade atual: 4.1241
# Processadas 51800 amostras, 2 clouds criadas
# Qualidade atual: 4.0571
# Processadas 51900 amostras, 2 clouds criadas
# Qualidade atual: 3.9985
# Processadas 52000 amostras, 2 clouds criadas
# Qualidade atual: 3.9078
# Processadas 52100 amostras, 2 clouds criadas
# Qualidade atual: 3.8414
# Processadas 52200 amostras, 2 clouds criadas
# Qualidade atual: 3.7884
# Processadas 52300 amostras, 2 clouds criadas
# Qualidade atual: 3.7256
# Processadas 52400 amostras, 2 clouds criadas
# Qualidade atual: 3.6701
# Processadas 52500 amostras, 2 clouds criadas
# Qualidade atual: 3.5819
# Processadas 52600 amostras, 2 clouds criadas
# Qualidade atual: 3.5357
# Processadas 52700 amostras, 2 clouds criadas
# Qualidade atual: 3.4808
# Processadas 52800 amostras, 2 clouds criadas
# Qualidade atual: 3.3814
# Processadas 52900 amostras, 2 clouds criadas
# Qualidade atual: 3.3402
# Processadas 53000 amostras, 2 clouds criadas
# Qualidade atual: 3.2955
# Processadas 53100 amostras, 2 clouds criadas
# Qualidade atual: 3.2435
# Processadas 53200 amostras, 2 clouds criadas
# Qualidade atual: 3.1906
# Processadas 53300 amostras, 2 clouds criadas
# Qualidade atual: 3.1317
# Processadas 53400 amostras, 2 clouds criadas
# Qualidade atual: 3.0961
# Processadas 53500 amostras, 2 clouds criadas
# Qualidade atual: 3.0575
# Processadas 53600 amostras, 2 clouds criadas
# Qualidade atual: 0.0195
# Processadas 53700 amostras, 2 clouds criadas
# Qualidade atual: 0.0194
# Processadas 53800 amostras, 2 clouds criadas
# Qualidade atual: 0.0194
# Processadas 53900 amostras, 2 clouds criadas
# Qualidade atual: 0.0194
# Processadas 54000 amostras, 2 clouds criadas
# Qualidade atual: 0.0193
# Processadas 54100 amostras, 2 clouds criadas
# Qualidade atual: 0.0193
# Processadas 54200 amostras, 2 clouds criadas
# Qualidade atual: 0.0192
# Processadas 54300 amostras, 2 clouds criadas
# Qualidade atual: 0.0192
# Processadas 54400 amostras, 2 clouds criadas
# Qualidade atual: 0.0192
# Processadas 54500 amostras, 2 clouds criadas
# Qualidade atual: 0.0192
# Processadas 54600 amostras, 2 clouds criadas
# Qualidade atual: 0.0192
# Processadas 54700 amostras, 2 clouds criadas
# Qualidade atual: 0.0192
# Processadas 54800 amostras, 2 clouds criadas
# Qualidade atual: 0.0191
# Processadas 54900 amostras, 2 clouds criadas
# Qualidade atual: 0.0191
# [k=55000] x = [1.         0.         0.         0.         0.00697289]
# Processadas 55000 amostras, 2 clouds criadas
# Qualidade atual: 0.0191
# Processadas 55100 amostras, 2 clouds criadas
# Qualidade atual: 0.0190
# Processadas 55200 amostras, 2 clouds criadas
# Qualidade atual: 0.0190
# Processadas 55300 amostras, 2 clouds criadas
# Qualidade atual: 0.0190
# Processadas 55400 amostras, 2 clouds criadas
# Qualidade atual: 0.0189
# Processadas 55500 amostras, 2 clouds criadas
# Qualidade atual: 0.0189
# Processadas 55600 amostras, 2 clouds criadas
# Qualidade atual: 0.0189
# Processadas 55700 amostras, 2 clouds criadas
# Qualidade atual: 0.0188
# Processadas 55800 amostras, 2 clouds criadas
# Qualidade atual: 0.0188
# Processadas 55900 amostras, 2 clouds criadas
# Qualidade atual: 0.0188
# Processadas 56000 amostras, 2 clouds criadas
# Qualidade atual: 0.0187
# Processadas 56100 amostras, 2 clouds criadas
# Qualidade atual: 0.0187
# Processadas 56200 amostras, 2 clouds criadas
# Qualidade atual: 0.0187
# Processadas 56300 amostras, 2 clouds criadas
# Qualidade atual: 0.0187
# Processadas 56400 amostras, 2 clouds criadas
# Qualidade atual: 0.0186
# Processadas 56500 amostras, 2 clouds criadas
# Qualidade atual: 0.0186
# Processadas 56600 amostras, 2 clouds criadas
# Qualidade atual: 0.0186
# Processadas 56700 amostras, 2 clouds criadas
# Qualidade atual: 0.0185
# Processadas 56800 amostras, 2 clouds criadas
# Qualidade atual: 0.0185
# Processadas 56900 amostras, 2 clouds criadas
# Qualidade atual: 0.0185
# Processadas 57000 amostras, 2 clouds criadas
# Qualidade atual: 0.0184
# Processadas 57100 amostras, 2 clouds criadas
# Qualidade atual: 0.0184
# Processadas 57200 amostras, 2 clouds criadas
# Qualidade atual: 0.0184
# Processadas 57300 amostras, 2 clouds criadas
# Qualidade atual: 0.0183
# Processadas 57400 amostras, 2 clouds criadas
# Qualidade atual: 0.0183
# Processadas 57500 amostras, 2 clouds criadas
# Qualidade atual: 0.0183
# Processadas 57600 amostras, 2 clouds criadas
# Qualidade atual: 0.0183
# Processadas 57700 amostras, 2 clouds criadas
# Qualidade atual: 0.0182
# Processadas 57800 amostras, 2 clouds criadas
# Qualidade atual: 0.0182
# Processadas 57900 amostras, 2 clouds criadas
# Qualidade atual: 0.0182
# Processadas 58000 amostras, 2 clouds criadas
# Qualidade atual: 0.0181
# Processadas 58100 amostras, 2 clouds criadas
# Qualidade atual: 0.0181
# Processadas 58200 amostras, 2 clouds criadas
# Qualidade atual: 0.0181
# Processadas 58300 amostras, 2 clouds criadas
# Qualidade atual: 0.0180
# Processadas 58400 amostras, 2 clouds criadas
# Qualidade atual: 0.0180
# Processadas 58500 amostras, 2 clouds criadas
# Qualidade atual: 0.0180
# Processadas 58600 amostras, 2 clouds criadas
# Qualidade atual: 0.0180
# Processadas 58700 amostras, 2 clouds criadas
# Qualidade atual: 0.0179
# Processadas 58800 amostras, 2 clouds criadas
# Qualidade atual: 0.0179
# Processadas 58900 amostras, 2 clouds criadas
# Qualidade atual: 0.0179
# Processadas 59000 amostras, 2 clouds criadas
# Qualidade atual: 0.0178
# Processadas 59100 amostras, 2 clouds criadas
# Qualidade atual: 0.0178
# Processadas 59200 amostras, 3 clouds criadas
# Qualidade atual: 0.0570
# Processadas 59300 amostras, 3 clouds criadas
# Qualidade atual: 0.0569
# Processadas 59400 amostras, 3 clouds criadas
# Qualidade atual: 0.0568
# Processadas 59500 amostras, 3 clouds criadas
# Qualidade atual: 0.0567
# Processadas 59600 amostras, 3 clouds criadas
# Qualidade atual: 0.0566
# Processadas 59700 amostras, 3 clouds criadas
# Qualidade atual: 0.0565
# Processadas 59800 amostras, 3 clouds criadas
# Qualidade atual: 0.0564
# Processadas 59900 amostras, 3 clouds criadas
# Qualidade atual: 0.0563
# [k=60000] x = [1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.0494e-05]
# Processadas 60000 amostras, 3 clouds criadas
# Qualidade atual: 0.0562
# Processadas 60100 amostras, 3 clouds criadas
# Qualidade atual: 0.0561
# Processadas 60200 amostras, 3 clouds criadas
# Qualidade atual: 0.0561
# Processadas 60300 amostras, 3 clouds criadas
# Qualidade atual: 0.0560
# Processadas 60400 amostras, 3 clouds criadas
# Qualidade atual: 0.0559
# Processadas 60500 amostras, 3 clouds criadas
# Qualidade atual: 0.0558
# Processadas 60600 amostras, 3 clouds criadas
# Qualidade atual: 0.0557
# Processadas 60700 amostras, 3 clouds criadas
# Qualidade atual: 0.0556
# Processadas 60800 amostras, 3 clouds criadas
# Qualidade atual: 0.0555
# Processadas 60900 amostras, 3 clouds criadas
# Qualidade atual: 0.0554
# Processadas 61000 amostras, 3 clouds criadas
# Qualidade atual: 0.0553
# Processadas 61100 amostras, 3 clouds criadas
# Qualidade atual: 0.0552
# Processadas 61200 amostras, 3 clouds criadas
# Qualidade atual: 0.0551
# Processadas 61300 amostras, 3 clouds criadas
# Qualidade atual: 0.0551
# Processadas 61400 amostras, 3 clouds criadas
# Qualidade atual: 0.0550
# Processadas 61500 amostras, 3 clouds criadas
# Qualidade atual: 0.0549
# Processadas 61600 amostras, 3 clouds criadas
# Qualidade atual: 0.0548
# Processadas 61700 amostras, 3 clouds criadas
# Qualidade atual: 0.0547
# Processadas 61800 amostras, 3 clouds criadas
# Qualidade atual: 0.0546
# Processadas 61900 amostras, 3 clouds criadas
# Qualidade atual: 0.0545
# Processadas 62000 amostras, 3 clouds criadas
# Qualidade atual: 0.0544
# Processadas 62100 amostras, 3 clouds criadas
# Qualidade atual: 0.0544
# Processadas 62200 amostras, 3 clouds criadas
# Qualidade atual: 0.0543
# Processadas 62300 amostras, 3 clouds criadas
# Qualidade atual: 0.0542
# Processadas 62400 amostras, 3 clouds criadas
# Qualidade atual: 0.0541
# Processadas 62500 amostras, 3 clouds criadas
# Qualidade atual: 0.0540
# Processadas 62600 amostras, 3 clouds criadas
# Qualidade atual: 0.0539
# Processadas 62700 amostras, 3 clouds criadas
# Qualidade atual: 0.0538
# Processadas 62800 amostras, 3 clouds criadas
# Qualidade atual: 0.0538
# Processadas 62900 amostras, 3 clouds criadas
# Qualidade atual: 0.0537
# Processadas 63000 amostras, 3 clouds criadas
# Qualidade atual: 0.0536
# Processadas 63100 amostras, 3 clouds criadas
# Qualidade atual: 0.0535
# Processadas 63200 amostras, 3 clouds criadas
# Qualidade atual: 0.0534
# Processadas 63300 amostras, 3 clouds criadas
# Qualidade atual: 0.0533
# Processadas 63400 amostras, 3 clouds criadas
# Qualidade atual: 0.0533
# Processadas 63500 amostras, 3 clouds criadas
# Qualidade atual: 0.0532
# Processadas 63600 amostras, 3 clouds criadas
# Qualidade atual: 0.0531
# Processadas 63700 amostras, 3 clouds criadas
# Qualidade atual: 0.0530
# Processadas 63800 amostras, 3 clouds criadas
# Qualidade atual: 0.0529
# Processadas 63900 amostras, 3 clouds criadas
# Qualidade atual: 0.0528
# Processadas 64000 amostras, 3 clouds criadas
# Qualidade atual: 0.0528
# Processadas 64100 amostras, 3 clouds criadas
# Qualidade atual: 0.0527
# Processadas 64200 amostras, 3 clouds criadas
# Qualidade atual: 0.0526
# Processadas 64300 amostras, 3 clouds criadas
# Qualidade atual: 0.0525
# Processadas 64400 amostras, 3 clouds criadas
# Qualidade atual: 0.0524
# Processadas 64500 amostras, 3 clouds criadas
# Qualidade atual: 0.0524
# Processadas 64600 amostras, 3 clouds criadas
# Qualidade atual: 0.0523
# Processadas 64700 amostras, 3 clouds criadas
# Qualidade atual: 0.0522
# Processadas 64800 amostras, 3 clouds criadas
# Qualidade atual: 0.0521
# Processadas 64900 amostras, 3 clouds criadas
# Qualidade atual: 0.0520
# [k=65000] x = [1.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 2.1653e-05]
# Processadas 65000 amostras, 3 clouds criadas
# Qualidade atual: 0.0520
# Processadas 65100 amostras, 3 clouds criadas
# Qualidade atual: 0.0519
# Processadas 65200 amostras, 3 clouds criadas
# Qualidade atual: 0.0518
# Processadas 65300 amostras, 3 clouds criadas
# Qualidade atual: 0.0517
# Processadas 65400 amostras, 3 clouds criadas
# Qualidade atual: 0.0517
# Processadas 65500 amostras, 3 clouds criadas
# Qualidade atual: 0.0516
# Processadas 65600 amostras, 3 clouds criadas
# Qualidade atual: 0.0515
# Processadas 65700 amostras, 3 clouds criadas
# Qualidade atual: 0.0514
# Processadas 65800 amostras, 3 clouds criadas
# Qualidade atual: 0.0513
# Processadas 65900 amostras, 3 clouds criadas
# Qualidade atual: 0.0513
# Processadas 66000 amostras, 3 clouds criadas
# Qualidade atual: 0.0512
# Processadas 66100 amostras, 3 clouds criadas
# Qualidade atual: 0.0511
# Processadas 66200 amostras, 3 clouds criadas
# Qualidade atual: 0.0510
# Processadas 66300 amostras, 3 clouds criadas
# Qualidade atual: 0.0510
# Processadas 66400 amostras, 3 clouds criadas
# Qualidade atual: 0.0509
# Processadas 66500 amostras, 3 clouds criadas
# Qualidade atual: 0.0508
# Processadas 66600 amostras, 3 clouds criadas
# Qualidade atual: 0.0507
# Processadas 66700 amostras, 3 clouds criadas
# Qualidade atual: 0.0507
# Processadas 66800 amostras, 3 clouds criadas
# Qualidade atual: 0.0506
# Processadas 66900 amostras, 3 clouds criadas
# Qualidade atual: 0.0505
# Processadas 67000 amostras, 3 clouds criadas
# Qualidade atual: 0.0504
# Processadas 67100 amostras, 3 clouds criadas
# Qualidade atual: 0.0504
# Processadas 67200 amostras, 3 clouds criadas
# Qualidade atual: 0.0503
# Processadas 67300 amostras, 3 clouds criadas
# ...
# Processadas 120300 amostras, 8 clouds criadas
# Qualidade atual: 20.9180
# Processadas 120400 amostras, 8 clouds criadas
# Qualidade atual: 20.9174
# Processadas 120500 amostras, 8 clouds criadas
# Qualidade atual: 20.9167
# Processadas 120600 amostras, 8 clouds criadas
# Qualidade atual: 20.9160
# Processadas 120700 amostras, 8 clouds criadas
# Qualidade atual: 20.8528
# Processadas 120800 amostras, 8 clouds criadas
# Qualidade atual: 20.8522
# Processadas 120900 amostras, 8 clouds criadas
# Qualidade atual: 20.8515
# Processadas 121000 amostras, 8 clouds criadas
# Qualidade atual: 20.8508
# Processadas 121100 amostras, 8 clouds criadas
# Qualidade atual: 20.8502
# Processadas 121200 amostras, 8 clouds criadas
# Qualidade atual: 20.8495
# Processadas 121300 amostras, 8 clouds criadas
# Qualidade atual: 20.8489
# Processadas 121400 amostras, 8 clouds criadas
# Qualidade atual: 20.8482
# Processadas 121500 amostras, 8 clouds criadas
# Qualidade atual: 20.8476
# Processadas 121600 amostras, 8 clouds criadas
# Qualidade atual: 20.8469
# Processadas 121700 amostras, 8 clouds criadas
# Qualidade atual: 20.7352
# Processadas 121800 amostras, 8 clouds criadas
# Qualidade atual: 20.7346
# Processadas 121900 amostras, 8 clouds criadas
# Qualidade atual: 20.7339
# Processadas 122000 amostras, 8 clouds criadas
# Qualidade atual: 20.7333
# Processadas 122100 amostras, 8 clouds criadas
# Qualidade atual: 20.7326
# Processadas 122200 amostras, 8 clouds criadas
# Qualidade atual: 20.6168
# Processadas 122300 amostras, 8 clouds criadas
# Qualidade atual: 20.5930
# Processadas 122400 amostras, 8 clouds criadas
# Qualidade atual: 20.5924
# Processadas 122500 amostras, 8 clouds criadas
# Qualidade atual: 20.5917
# Processadas 122600 amostras, 8 clouds criadas
# Qualidade atual: 20.5911
# Processadas 122700 amostras, 8 clouds criadas
# Qualidade atual: 20.5904
# Processadas 122800 amostras, 8 clouds criadas
# Qualidade atual: 20.5898
# Processadas 122900 amostras, 8 clouds criadas
# Qualidade atual: 20.5891
# Processadas 123000 amostras, 8 clouds criadas
# Qualidade atual: 20.5885
# Processadas 123100 amostras, 8 clouds criadas
# Qualidade atual: 20.5879
# Processadas 123200 amostras, 8 clouds criadas
# Qualidade atual: 20.5872
# Processadas 123300 amostras, 8 clouds criadas
# Qualidade atual: 20.5866
# Processadas 123400 amostras, 8 clouds criadas
# Qualidade atual: 20.5860
# Processadas 123500 amostras, 8 clouds criadas
# Qualidade atual: 20.5853
# Processadas 123600 amostras, 8 clouds criadas
# Qualidade atual: 20.5847
# Processadas 123700 amostras, 8 clouds criadas
# Qualidade atual: 20.5841
# Processadas 123800 amostras, 8 clouds criadas
# Qualidade atual: 20.5834
# Processadas 123900 amostras, 8 clouds criadas
# Qualidade atual: 20.5828
# Processadas 124000 amostras, 8 clouds criadas
# Qualidade atual: 20.5822
# Processadas 124100 amostras, 8 clouds criadas
# Qualidade atual: 20.5816
# Processadas 124200 amostras, 8 clouds criadas
# Qualidade atual: 20.5809
# Processadas 124300 amostras, 8 clouds criadas
# Qualidade atual: 20.5803
# Processadas 124400 amostras, 8 clouds criadas
# Qualidade atual: 20.5797
# Processadas 124500 amostras, 8 clouds criadas
# Qualidade atual: 20.5791
# Processadas 124600 amostras, 8 clouds criadas
# Qualidade atual: 20.5784
# Processadas 124700 amostras, 8 clouds criadas
# Qualidade atual: 20.5778
# Processadas 124800 amostras, 8 clouds criadas
# Qualidade atual: 20.5772
# Processadas 124900 amostras, 8 clouds criadas
# Qualidade atual: 20.5766
# [k=125000] x = [1.e+00 0.e+00 0.e+00 0.e+00 2.e-08]
# Processadas 125000 amostras, 8 clouds criadas
# Qualidade atual: 20.5760
# Processadas 125100 amostras, 8 clouds criadas
# Qualidade atual: 20.5754
# Processadas 125200 amostras, 8 clouds criadas
# Qualidade atual: 20.5747
# Processadas 125300 amostras, 8 clouds criadas
# Qualidade atual: 20.5741
# Processadas 125400 amostras, 8 clouds criadas
# Qualidade atual: 20.5735
# Processadas 125500 amostras, 8 clouds criadas
# Qualidade atual: 20.5729
# Processadas 125600 amostras, 8 clouds criadas
# Qualidade atual: 20.5723
# Processadas 125700 amostras, 8 clouds criadas
# Qualidade atual: 20.5717
# Processadas 125800 amostras, 8 clouds criadas
# Qualidade atual: 20.5711
# Processadas 125900 amostras, 8 clouds criadas
# Qualidade atual: 20.5705
# Processadas 126000 amostras, 8 clouds criadas
# Qualidade atual: 20.5699
# Processadas 126100 amostras, 8 clouds criadas
# Qualidade atual: 20.5692
# Processadas 126200 amostras, 8 clouds criadas
# Qualidade atual: 20.5686
# Processadas 126300 amostras, 8 clouds criadas
# Qualidade atual: 20.5680
# Processadas 126400 amostras, 8 clouds criadas
# Qualidade atual: 20.5674
# Processadas 126500 amostras, 8 clouds criadas
# Qualidade atual: 20.5668
# Processadas 126600 amostras, 8 clouds criadas
# Qualidade atual: 20.5662
# Processadas 126700 amostras, 8 clouds criadas
# Qualidade atual: 20.5656
# Processadas 126800 amostras, 8 clouds criadas
# Qualidade atual: 20.5650
# Processadas 126900 amostras, 8 clouds criadas
# Qualidade atual: 20.5644
# Processadas 127000 amostras, 8 clouds criadas
# Qualidade atual: 20.5638
# Processadas 127100 amostras, 8 clouds criadas
# Qualidade atual: 20.5632
# Processadas 127200 amostras, 8 clouds criadas
# Qualidade atual: 20.5626
# Processadas 127300 amostras, 8 clouds criadas
# Qualidade atual: 20.5620
# Processadas 127400 amostras, 8 clouds criadas
# Qualidade atual: 20.5614
# Processadas 127500 amostras, 8 clouds criadas
# Qualidade atual: 20.4462
# Processadas 127600 amostras, 8 clouds criadas
# Qualidade atual: 20.4456
# Processadas 127700 amostras, 8 clouds criadas
# Qualidade atual: 20.4450
# Processadas 127800 amostras, 8 clouds criadas
# Qualidade atual: 26.1094
# Processadas 127900 amostras, 8 clouds criadas
# Qualidade atual: 26.1088
# Processadas 128000 amostras, 8 clouds criadas
# Qualidade atual: 33.7247
# Processadas 128100 amostras, 8 clouds criadas
# Qualidade atual: 33.7241
# Processadas 128200 amostras, 8 clouds criadas
# Qualidade atual: 34.3269
# Processadas 128300 amostras, 8 clouds criadas
# Qualidade atual: 34.3263
# Processadas 128400 amostras, 8 clouds criadas
# Qualidade atual: 34.3257
# Processadas 128500 amostras, 8 clouds criadas
# Qualidade atual: 35.3867
# Processadas 128600 amostras, 8 clouds criadas
# Qualidade atual: 35.3861
# Processadas 128700 amostras, 8 clouds criadas
# Qualidade atual: 34.3674
# Processadas 128800 amostras, 8 clouds criadas
# Qualidade atual: 34.3667
# Processadas 128900 amostras, 8 clouds criadas
# Qualidade atual: 34.3661
# Processadas 129000 amostras, 8 clouds criadas
# Qualidade atual: 34.3655
# Processadas 129100 amostras, 8 clouds criadas
# Qualidade atual: 34.3649
# Processadas 129200 amostras, 8 clouds criadas
# Qualidade atual: 34.3643
# Processadas 129300 amostras, 8 clouds criadas
# Qualidade atual: 34.3637
# Processadas 129400 amostras, 8 clouds criadas
# Qualidade atual: 34.3631
# Processadas 129500 amostras, 8 clouds criadas
# Qualidade atual: 34.3625
# Processadas 129600 amostras, 8 clouds criadas
# Qualidade atual: 34.3619
# Processadas 129700 amostras, 8 clouds criadas
# Qualidade atual: 34.3613
# Processadas 129800 amostras, 8 clouds criadas
# Qualidade atual: 34.3607
# Processadas 129900 amostras, 8 clouds criadas
# Qualidade atual: 34.3601
# [k=130000] x = [1.e+00 0.e+00 0.e+00 0.e+00 1.e-08]
# Processadas 130000 amostras, 8 clouds criadas
# Qualidade atual: 34.3595
# Processadas 130100 amostras, 8 clouds criadas
# Qualidade atual: 34.3589
# Processadas 130200 amostras, 8 clouds criadas
# Qualidade atual: 34.3583
# Processadas 130300 amostras, 8 clouds criadas
# Qualidade atual: 34.3577
# Processadas 130400 amostras, 8 clouds criadas
# Qualidade atual: 34.3571
# Processadas 130500 amostras, 8 clouds criadas
# Qualidade atual: 34.3565
# Processadas 130600 amostras, 8 clouds criadas
# Qualidade atual: 34.3559
# Processadas 130700 amostras, 8 clouds criadas
# Qualidade atual: 34.3553
# Processadas 130800 amostras, 8 clouds criadas
# Qualidade atual: 34.3547
# Processadas 130900 amostras, 8 clouds criadas
# Qualidade atual: 34.3541
# Processadas 131000 amostras, 8 clouds criadas
# Qualidade atual: 34.3535
# Processadas 131100 amostras, 8 clouds criadas
# Qualidade atual: 34.3529
# Processadas 131200 amostras, 8 clouds criadas
# Qualidade atual: 34.3523
# Processadas 131300 amostras, 8 clouds criadas
# Qualidade atual: 34.3517
# Processadas 131400 amostras, 8 clouds criadas
# Qualidade atual: 34.3511
# Processadas 131500 amostras, 8 clouds criadas
# Qualidade atual: 34.3505
# Processadas 131600 amostras, 8 clouds criadas
# Qualidade atual: 39.3283
# Processadas 131700 amostras, 8 clouds criadas
# Qualidade atual: 39.3277
# Processadas 131800 amostras, 8 clouds criadas
# Qualidade atual: 39.3271
# Processadas 131900 amostras, 8 clouds criadas
# Qualidade atual: 39.3265
# Processadas 132000 amostras, 8 clouds criadas
# Qualidade atual: 39.3260
# Processadas 132100 amostras, 8 clouds criadas
# Qualidade atual: 39.3254
# Processadas 132200 amostras, 8 clouds criadas
# Qualidade atual: 39.3248
# Processadas 132300 amostras, 8 clouds criadas
# Qualidade atual: 39.3242
# Processadas 132400 amostras, 9 clouds criadas
# Qualidade atual: 30.8673
# Processadas 132500 amostras, 9 clouds criadas
# Qualidade atual: 7.2671
# Processadas 132600 amostras, 9 clouds criadas
# Qualidade atual: 6.1966
# Processadas 132700 amostras, 9 clouds criadas
# Qualidade atual: 5.6601
# Processadas 132800 amostras, 9 clouds criadas
# Qualidade atual: 5.4247
# Processadas 132900 amostras, 9 clouds criadas
# Qualidade atual: 5.4177
# Processadas 133000 amostras, 9 clouds criadas
# Qualidade atual: 5.3928
# Processadas 133100 amostras, 9 clouds criadas
# Qualidade atual: 5.3052
# Processadas 133200 amostras, 9 clouds criadas
# Qualidade atual: 5.1880
# Processadas 133300 amostras, 9 clouds criadas
# Qualidade atual: 5.1604
# Processadas 133400 amostras, 9 clouds criadas
# Qualidade atual: 17.6649
# Processadas 133500 amostras, 12 clouds criadas
# Qualidade atual: 12.9879
# Processadas 133600 amostras, 13 clouds criadas
# Qualidade atual: 12.5662
# Processadas 133700 amostras, 14 clouds criadas
# Qualidade atual: 11833.6476
# Processadas 133800 amostras, 14 clouds criadas
# Qualidade atual: 1855.6727
# Processadas 133900 amostras, 14 clouds criadas
# Qualidade atual: 1041.9626
# Processadas 134000 amostras, 14 clouds criadas
# Qualidade atual: 707.5594
# Processadas 134100 amostras, 14 clouds criadas
# Qualidade atual: 538.7750
# Processadas 134200 amostras, 14 clouds criadas
# Qualidade atual: 436.7090
# Processadas 134300 amostras, 14 clouds criadas
# Qualidade atual: 368.5048
# Processadas 134400 amostras, 14 clouds criadas
# Qualidade atual: 22.6748
# Processadas 134500 amostras, 14 clouds criadas
# Qualidade atual: 22.6747
# Processadas 134600 amostras, 14 clouds criadas
# Qualidade atual: 1733.3997
# Processadas 134700 amostras, 14 clouds criadas
# Qualidade atual: 1577.4300
# Processadas 134800 amostras, 14 clouds criadas
# Qualidade atual: 776.6751
# Processadas 134900 amostras, 14 clouds criadas
# Qualidade atual: 539.5589
# [k=135000] x = [1.00e+00 0.00e+00 0.00e+00 0.00e+00 1.65e-07]
# Processadas 135000 amostras, 14 clouds criadas
# Qualidade atual: 473.1657
# Processadas 135100 amostras, 14 clouds criadas
# Qualidade atual: 439.3904
# Processadas 135200 amostras, 14 clouds criadas
# Qualidade atual: 361.4293
# Processadas 135300 amostras, 14 clouds criadas
# Qualidade atual: 296.6295
# Processadas 135400 amostras, 14 clouds criadas
# Qualidade atual: 223.1396
# Processadas 135500 amostras, 14 clouds criadas
# Qualidade atual: 236.5956
# Processadas 135600 amostras, 14 clouds criadas
# Qualidade atual: 161.5882
# Processadas 135700 amostras, 14 clouds criadas
# Qualidade atual: 134.4820
# Processadas 135800 amostras, 14 clouds criadas
# Qualidade atual: 120.4118
# Processadas 135900 amostras, 14 clouds criadas
# Qualidade atual: 115.4184
# Processadas 136000 amostras, 14 clouds criadas
# Qualidade atual: 112.3784
# Processadas 136100 amostras, 14 clouds criadas
# Qualidade atual: 106.8548
# Processadas 136200 amostras, 7 clouds criadas
# Qualidade atual: 36.5419
# Processadas 136300 amostras, 7 clouds criadas
# Qualidade atual: 26.7926
# Processadas 136400 amostras, 7 clouds criadas
# Qualidade atual: 24.6880
# Processadas 136500 amostras, 7 clouds criadas
# Qualidade atual: 23.6659
# Processadas 136600 amostras, 7 clouds criadas
# Qualidade atual: 481.0114
# Processadas 136700 amostras, 7 clouds criadas
# Qualidade atual: 241.4408
# Processadas 136800 amostras, 7 clouds criadas
# Qualidade atual: 139.2188
# Processadas 136900 amostras, 7 clouds criadas
# Qualidade atual: 106.2390
# Processadas 137000 amostras, 7 clouds criadas
# Qualidade atual: 89.6588
# Processadas 137100 amostras, 7 clouds criadas
# Qualidade atual: 980.7688
# Processadas 137200 amostras, 7 clouds criadas
# Qualidade atual: 432.0974
# Processadas 137300 amostras, 7 clouds criadas
# Qualidade atual: 337.3910
# Processadas 137400 amostras, 7 clouds criadas
# Qualidade atual: 317.0941
# Processadas 137500 amostras, 7 clouds criadas
# Qualidade atual: 237.6305
# Processadas 137600 amostras, 7 clouds criadas
# Qualidade atual: 189.6338
# Processadas 137700 amostras, 7 clouds criadas
# Qualidade atual: 147.4684
# Processadas 137800 amostras, 7 clouds criadas
# Qualidade atual: 126.8641
# Processadas 137900 amostras, 7 clouds criadas
# Qualidade atual: 119.2551
# Processadas 138000 amostras, 7 clouds criadas
# Qualidade atual: 119.2550
# Processadas 138100 amostras, 7 clouds criadas
# Qualidade atual: 115.1976
# Processadas 138200 amostras, 7 clouds criadas
# Qualidade atual: 109.7142
# Processadas 138300 amostras, 7 clouds criadas
# Qualidade atual: 100.9165
# Processadas 138400 amostras, 7 clouds criadas
# Qualidade atual: 99.0918
# Processadas 138500 amostras, 7 clouds criadas
# Qualidade atual: 95.6934
# Processadas 138600 amostras, 7 clouds criadas
# Qualidade atual: 91.1183
# Processadas 138700 amostras, 7 clouds criadas
# Qualidade atual: 87.7008
# Processadas 138800 amostras, 7 clouds criadas
# Qualidade atual: 84.6197
# Processadas 138900 amostras, 7 clouds criadas
# Qualidade atual: 75.1022
# Processadas 139000 amostras, 7 clouds criadas
# Qualidade atual: 70.4341
# Processadas 139100 amostras, 7 clouds criadas
# Qualidade atual: 68.3935
# Processadas 139200 amostras, 7 clouds criadas
# Qualidade atual: 67.1244
# Processadas 139300 amostras, 7 clouds criadas
# Qualidade atual: 65.7763
# Processadas 139400 amostras, 7 clouds criadas
# Qualidade atual: 63.9644
# Processadas 139500 amostras, 7 clouds criadas
# Qualidade atual: 61.5654
# Processadas 139600 amostras, 7 clouds criadas
# Qualidade atual: 58.1805
# Processadas 139700 amostras, 7 clouds criadas
# Qualidade atual: 56.2871
# Processadas 139800 amostras, 7 clouds criadas
# Qualidade atual: 54.7406
# Processadas 139900 amostras, 7 clouds criadas
# Qualidade atual: 52.7351
# [k=140000] x = [0. 0. 0. 0. 0.]
# Processadas 140000 amostras, 7 clouds criadas
# Qualidade atual: 52.0251
# Processadas 140100 amostras, 7 clouds criadas
# Qualidade atual: 51.0186
# Processadas 140200 amostras, 7 clouds criadas
# Qualidade atual: 28848.6408
# Processadas 140300 amostras, 7 clouds criadas
# Qualidade atual: 14791.5980
# Processadas 140400 amostras, 7 clouds criadas
# Qualidade atual: 11882.7554
# Processadas 140500 amostras, 7 clouds criadas
# Qualidade atual: 9928.3766
#
# Testes de consistência:
# Total de amostras processadas: 140544
# Soma de amostras registradas nas clouds: 140544
# Frequência de clouds:
# Counter({0: 140382, 6: 85, 1: 24, 3: 24, 4: 22, 2: 5, 5: 2})
#
# Resultados finais:
# Total de clouds: 7
# Métrica de qualidade: 9483.4274
#
# Cloud 0:
#   Núm. amostras: 140382
#   Centróide: [0.92258979 0.00965936 0.0532262  0.         0.04844577]
#   Variância: 0.7207
#   Amostras associadas: 140382
#
# Cloud 1:
#   Núm. amostras: 24
#   Centróide: [ 1.          0.          0.          0.         11.62030683]
#   Variância: 0.0070
#   Amostras associadas: 24
#
# Cloud 2:
#   Núm. amostras: 5
#   Centróide: [1.         0.         0.         0.         8.87659349]
#   Variância: 0.0055
#   Amostras associadas: 5
#
# Cloud 3:
#   Núm. amostras: 24
#   Centróide: [ 1.          0.          0.          0.         23.27866234]
#   Variância: 5.6062
#   Amostras associadas: 24
#
# Cloud 4:
#   Núm. amostras: 22
#   Centróide: [1.         1.         0.         0.         3.15205081]
#   Variância: 0.0000
#   Amostras associadas: 22
#
# Cloud 5:
#   Núm. amostras: 2
#   Centróide: [1.         1.         0.         0.         3.11438558]
#   Variância: 0.0000
#   Amostras associadas: 2
#
# Cloud 6:
#   Núm. amostras: 85
#   Centróide: [0.01176471 0.         0.98823529 0.         5.91216789]
#   Variância: 2616.6156
#   Amostras associadas: 85

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D
from matplotlib.colors import TABLEAU_COLORS

#`ac.classIndex` tem os rótulos das clouds (mesmo comprimento das amostras processadas)

# Quantidade de amostras a visualizar
j = 140544
features_plot = features[:j]
classes = np.array(ac.classIndex[:j])

# Features que serão usadas
nomes = ['tcp.flags.ack', 'tcp.flags.fin', 'tcp.flags.syn', 'tcp.flags.urg', 'tcp.time_delta']

# Obter os clusters únicos e mapear cores bem distintas
clusters_unicos = sorted(set(classes))
num_clusters = len(clusters_unicos)

# Usar cores do TABLEAU_COLORS ou estender com outras se necessário
cores_disponiveis = list(TABLEAU_COLORS.values())
if num_clusters > len(cores_disponiveis):
    from matplotlib import cm
    cmap = cm.get_cmap('hsv', num_clusters)
    cores_disponiveis = [cmap(i) for i in range(num_clusters)]
    
# Mapeia índice da nuvem para uma cor única
mapa_cores = {c: cores_disponiveis[i] for i, c in enumerate(clusters_unicos)}
cores_amostras = [mapa_cores[c] for c in classes]

# Criar o gráfico com subplots para cada feature
fig, axs = plt.subplots(5, 1, figsize=(15, 10), sharex=True)

for i in range(5):
    axs[i].scatter(range(j), features_plot[:, i], c=cores_amostras, s=2)
    axs[i].set_ylabel(nomes[i])

axs[-1].set_xlabel('Índice da amostra')
fig.suptitle('Série temporal com cores distintas por clouds (AutoCloud)', fontsize=16)

# Criar a legenda
legenda_elementos = [
    Line2D([0], [0], marker='o', color='w', label=f'Cloud {c}', 
           markerfacecolor=cor, markersize=8) 
    for c, cor in mapa_cores.items()
]
axs[0].legend(handles=legenda_elementos, title="Clouds", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout(rect=[0, 0, 0.85, 0.97])
plt.show()
